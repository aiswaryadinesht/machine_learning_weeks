# %%
import pandas as pd
from sklearn.impute import SimpleImputer

# Example dataset
data = {'Age': [25, 30, None, 35, None], 'Salary': [50000, 60000, 58000, None, 52000],
       "department":["cs","bio","com","cs","bio"]}
df = pd.DataFrame(data)

# Imputation
imputer = SimpleImputer(strategy='most_frequent')
df['Age'] = imputer.fit_transform(df[['Age']])
df['Salary'] = imputer.fit_transform(df[['Salary']])
encoded=pd.get_dummies(df,columns=["department"])
df2=pd.DataFrame(encoded)
df=df.merge(df2)
#df.drop(df["department"])

# %%
from sklearn.preprocessing import StandardScaler, MinMaxScaler

scaler = StandardScaler()
scaled_data = scaler.fit_transform(df[['Salary']])

# %%
print(df)
# Out:
#     Age   Salary department  department_bio  department_com  department_cs
# 0  25.0  50000.0         cs           False           False           True
# 1  30.0  60000.0        bio            True           False          False
# 2  25.0  58000.0        com           False            True          False
# 3  35.0  50000.0         cs           False           False           True
# 4  25.0  52000.0        bio            True           False          False

# %%
print(df.describe())
print(df['department'].value_counts())
# Out:
#              Age       Salary
# count   5.000000      5.00000
# mean   28.000000  54000.00000
# std     4.472136   4690.41576
# min    25.000000  50000.00000
# 25%    25.000000  50000.00000
# 50%    25.000000  52000.00000
# 75%    30.000000  58000.00000
# max    35.000000  60000.00000
# department
# cs     2
# bio    2
# com    1
# Name: count, dtype: int64

# %%
import matplotlib.pyplot as plt
import seaborn as sns

sns.boxplot(x="department", y='Salary', data=df)
plt.show()

# %%
sns.heatmap(df[['Age','Salary']].corr(), annot=True)
plt.show()
