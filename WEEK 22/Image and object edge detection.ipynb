# %%
import cv2
import numpy as np
image=cv2.imread("image2.png")
image=cv2.resize(image,(300,300))
cv2.imshow("original image",image)

hsv_image=cv2.cvtColor(image,cv2.COLOR_BGR2HSV)
cv2.imshow("hsv image",hsv_image)

lower_blue = np.array([100, 150, 50])  # Lower bound of blue (H, S, V)
upper_blue = np.array([140, 255, 255])  # Upper bound of blue (H, S, V)

mask=cv2.inRange(hsv_image,lower_blue,upper_blue)
cv2.imshow("mask image",mask)

result = cv2.bitwise_and(image, image, mask=mask)
cv2.imshow("result image",mask)

cv2.waitKey(0)
cv2.destroyAllWindows()

# %%
import numpy as np
import cv2
kernel = np.ones((5, 5), np.uint8)  # Define a 5x5 kernel
mask = cv2.erode(mask, kernel, iterations=1)  # Remove small white spots
mask = cv2.dilate(mask, kernel, iterations=1)  # Restore object size

# %%
import cv2
import numpy as np

# Load the image
image = cv2.imread('image.jpeg')

# Apply average (mean) filter
kernel = np.ones((3, 3), np.float32) / 9
smoothed_image = cv2.filter2D(image, -1, kernel)

# Display the result
cv2.imshow("Original Image", image)
cv2.imshow("Smoothed Image", smoothed_image)
cv2.waitKey(0)
cv2.destroyAllWindows()

# %%
import cv2

# Load the image
image = cv2.imread('image.jpeg')

# Apply Gaussian filter
gaussian_smoothed = cv2.GaussianBlur(image, (5, 5), 0)

# Display the result
cv2.imshow("Original Image", image)
cv2.imshow("Gaussian Smoothed Image", gaussian_smoothed)
cv2.waitKey(0)
cv2.destroyAllWindows()

# %%
import cv2

# Load the image
image = cv2.imread('image.jpeg')

# Apply median filter
median_smoothed = cv2.medianBlur(image, 5)

# Display the result
cv2.imshow("Original Image", image)
cv2.imshow("Median Smoothed Image", median_smoothed)
cv2.waitKey(0)
cv2.destroyAllWindows()

# %%
import cv2

# Load the image
image = cv2.imread('image.jpeg')

# Apply bilateral filter
bilateral_smoothed = cv2.bilateralFilter(image, 9, 75, 75)

# Display the result
cv2.imshow("Original Image", image)
cv2.imshow("Bilateral Smoothed Image", bilateral_smoothed)
cv2.waitKey(0)
cv2.destroyAllWindows()

# %%
import cv2
import numpy as np

# Load the image in grayscale
image = cv2.imread('image.jpeg', cv2.IMREAD_GRAYSCALE)

# Compute gradients using Sobel operator
sobel_x = cv2.Sobel(image, cv2.CV_64F, 1, 0, ksize=3)  # Horizontal gradient
sobel_y = cv2.Sobel(image, cv2.CV_64F, 0, 1, ksize=3)  # Vertical gradient

# Compute gradient magnitude
gradient_magnitude = cv2.magnitude(sobel_x, sobel_y)

# Normalize to display
gradient_magnitude = cv2.convertScaleAbs(gradient_magnitude)

# Display results
cv2.imshow('Original Image', image)
cv2.imshow('Sobel X', cv2.convertScaleAbs(sobel_x))
cv2.imshow('Sobel Y', cv2.convertScaleAbs(sobel_y))
cv2.imshow('Gradient Magnitude', gradient_magnitude)
cv2.waitKey(0)
cv2.destroyAllWindows()

# %%
import cv2

# Load the image in grayscale
image = cv2.imread('image.jpeg', cv2.IMREAD_GRAYSCALE)

# Apply Sobel edge detection
sobel_edges = cv2.Sobel(image, cv2.CV_64F, 1, 1, ksize=3)
sobel_edges = cv2.convertScaleAbs(sobel_edges)

# Display the result
cv2.imshow('Original Image', image)
cv2.imshow('Sobel Edge Detection', sobel_edges)
cv2.waitKey(0)
cv2.destroyAllWindows()

# %%
import cv2

# Load the image in grayscale
image = cv2.imread('image.jpeg', cv2.IMREAD_GRAYSCALE)

# Apply Canny edge detection
canny_edges = cv2.Canny(image, 100, 200)

# Display the result
cv2.imshow('Original Image', image)
cv2.imshow('Canny Edge Detection', canny_edges)
cv2.waitKey(0)
cv2.destroyAllWindows()

# %%
import cv2

# Load the image in grayscale
image = cv2.imread('image.jpeg', cv2.IMREAD_GRAYSCALE)

# Apply Laplacian edge detection
laplacian_edges = cv2.Laplacian(image, cv2.CV_64F)
laplacian_edges = cv2.convertScaleAbs(laplacian_edges)

# Display the result
cv2.imshow('Original Image', image)
cv2.imshow('Laplacian Edge Detection', laplacian_edges)
cv2.waitKey(0)
cv2.destroyAllWindows()

# %%
import cv2
import matplotlib.pyplot as plt

# Load the image in grayscale
image = cv2.imread('image.jpeg', cv2.IMREAD_GRAYSCALE)

# Apply GaussianBlur to reduce noise
blurred_image = cv2.GaussianBlur(image, (5, 5), 1)

# Apply Canny Edge Detection
edges = cv2.Canny(blurred_image, 50, 150)

# Display the original image and the edges
plt.figure(figsize=(10, 5))
plt.subplot(1, 2, 1)
plt.imshow(image, cmap='gray')
plt.title('Original Image')
plt.axis('off')

plt.subplot(1, 2, 2)
plt.imshow(edges, cmap='gray')
plt.title('Canny Edge Detection')
plt.axis('off')

plt.tight_layout()
plt.show()

# %%
import cv2
import matplotlib.pyplot as plt

# Load the image in grayscale
image = cv2.imread('image.jpeg', cv2.IMREAD_GRAYSCALE)

# Apply GaussianBlur to reduce noise (optional)
blurred_image = cv2.GaussianBlur(image, (5, 5), 1)

# Apply Laplacian edge detection
laplacian = cv2.Laplacian(blurred_image, cv2.CV_64F, ksize=3)

# Convert to absolute values (edge intensity)
laplacian_abs = cv2.convertScaleAbs(laplacian)

# Display the results
plt.figure(figsize=(10, 5))
plt.subplot(1, 2, 1)
plt.imshow(image, cmap='gray')
plt.title('Original Image')
plt.axis('off')

plt.subplot(1, 2, 2)
plt.imshow(laplacian_abs, cmap='gray')
plt.title('Laplacian Edge Detection')
plt.axis('off')

plt.tight_layout()
plt.show()
