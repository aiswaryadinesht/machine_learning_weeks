# %%
import numpy as np
import cv2

# Create two sample images
image1 = np.zeros((400, 400), dtype="uint8")
image2 = np.zeros((400, 400), dtype="uint8")

cv2.rectangle(image1, (50, 50), (300, 300), 255, -1)  # White square
cv2.circle(image2, (200, 200), 150, 255, -1)          # White circle

# Bitwise operations
bitwise_and = cv2.bitwise_and(image1, image2)
bitwise_or = cv2.bitwise_or(image1, image2)
bitwise_xor = cv2.bitwise_xor(image1, image2)
bitwise_not = cv2.bitwise_not(image1)

# Display results
cv2.imshow("Image 1", image1)
cv2.imshow("Image 2", image2)
cv2.imshow("Bitwise AND", bitwise_and)
cv2.imshow("Bitwise OR", bitwise_or)
cv2.imshow("Bitwise XOR", bitwise_xor)
cv2.imshow("Bitwise NOT", bitwise_not)
cv2.waitKey(0)
cv2.destroyAllWindows()

# %%
import numpy as np
import cv2
# Load an image
image = cv2.imread("image1.png")

# Create a mask
mask = np.zeros(image.shape[:2], dtype="uint8")
cv2.circle(mask, (150, 150), 100, 255, -1)  # White circle mask

# Apply the mask
masked_image = cv2.bitwise_and(image, image, mask=mask)

# Display results
cv2.imshow("Original Image", image)
cv2.imshow("Mask", mask)
cv2.imshow("Masked Image", masked_image)
cv2.waitKey(0)
cv2.destroyAllWindows()

# %%
import numpy as np
import cv2
import matplotlib.pyplot as plt
# Load an color image in grayscale
img = cv2.imread('image1.png',cv2.IMREAD_GRAYSCALE)
plt.imshow(img,cmap='gray')
plt.show()

# imge=cv2.imread("image2.png",0)
# plt.imshow(imge)
# plt.show

#hold the window
# plt.waitforbuttonpress()
# plt.close('all')

# %%
# Draw a rectangle and text on the image
image = cv2.imread('image1.png')
cv2.rectangle(image, (50, 50), (200, 200), (255, 0, 0), 3)  # Blue rectangle
cv2.putText(image, 'OpenCV Text', (60, 40), cv2.FONT_HERSHEY_SIMPLEX, 1, (0, 255, 0), 2)  # Green text

# Convert BGR to RGB
image_rgb = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)

# Display the modified image
plt.imshow(image_rgb)
plt.title('Annotated Image')
plt.axis('off')
plt.show()

# %%
import numpy as np
import cv2
import matplotlib.pyplot as plt
# Read the image
image = cv2.imread('image1.png', cv2.IMREAD_GRAYSCALE)

# Apply Canny edge detection
edges = cv2.Canny(image, 100, 200)

# Display the original and processed images side by side
plt.figure(figsize=(10, 5))

plt.subplot(1, 2, 1)
plt.imshow(image, cmap='gray')
plt.title('Original Image')
plt.axis('off')

plt.subplot(1, 2, 2)
plt.imshow(edges, cmap='gray')
plt.title('Edge Detection')
plt.axis('off')

plt.show()

# %%
# Read an image
image = cv2.imread('pic.jpg')
image_rgb = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)

# Apply Gaussian blur
blurred = cv2.GaussianBlur(image_rgb, (15, 15), 0)

# Convert to grayscale
gray = cv2.cvtColor(image_rgb, cv2.COLOR_RGB2GRAY)

# Display the images
plt.figure(figsize=(15, 5))

plt.subplot(1, 3, 1)
plt.imshow(image_rgb)
plt.title('Original Image')
plt.axis('off')

plt.subplot(1, 3, 2)
plt.imshow(blurred)
plt.title('Blurred Image')
plt.axis('off')

plt.subplot(1, 3, 3)
plt.imshow(gray, cmap='gray')
plt.title('Grayscale Image')
plt.axis('off')

plt.show()
