# %%
import cv2
import numpy as  np

image=cv2.imread("image1.png")
cv2.imshow("image1",image)

resized_image=cv2.resize(image,(200,200))

img=cv2.cvtColor(image,cv2.COLOR_BGR2GRAY)

ret,thres=cv2.threshold(image,120,255,cv2.THRESH_BINARY)
ret1,thres1=cv2.threshold(image,120,255,cv2.THRESH_BINARY_INV)
ret2,thres2=cv2.threshold(image,100,255,cv2.THRESH_TRUNC)
ret3,thres3=cv2.threshold(image,120,255,cv2.THRESH_TOZERO)
ret4,thres4=cv2.threshold(image,120,255,cv2.THRESH_TOZERO_INV)


cv2.imshow("image thresh",thres)
cv2.imshow("image thresh1",thres1)
cv2.imshow("image thresh2",thres2)
cv2.imshow("image thresh3",thres3)
cv2.imshow("image thresh4",thres4)

cv2.waitKey(0)
cv2.destroyAllWindows()

# %%
import cv2
import numpy as np

imag=cv2.imread("image1.png")
# cv2.imshow("adapative window",imag)
re_imag=cv2.resize(imag,(300,300))
# cv2.imshow("adapative window",re_imag)

img=cv2.cvtColor(re_imag,cv2.COLOR_BGR2GRAY)

thresh=cv2.adaptiveThreshold(img,255,cv2.ADAPTIVE_THRESH_MEAN_C,cv2.THRESH_BINARY,199,5)

cv2.imshow("adapative window",thresh)
h
cv2.waitKey(0)
cv2.destroyAllWindows()
